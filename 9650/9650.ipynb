# %%
import pandas as pd
import numpy as np
import os

# %%
path=os.getcwd()
data_path=path+'/data/'
group_names=[]
with open(data_path+'names.txt','r') as f:
    for line in f:
        group_names.append(line[:-1])
artists=[]
with open(data_path+'artists.txt','r') as f:
    for line in f:
        artists.append(line[:-1])
songs=[]
with open(data_path+'songs.txt','r') as f:
    for line in f:
        songs.append(line[:-1])
year=range(1965,2016)
year_rank=range(1,100)
ids=range(1,10000)
df=pd.DataFrame({
    'id':np.random.choice(ids,10000),
    'year':np.random.choice(year,10000),
    'year_rank':np.random.choice(year_rank,10000),
    'group_name':np.random.choice(group_names,10000),
    'artist':np.random.choice(artists,10000),
    'song':np.random.choice(songs,10000)
}   
)
# Out:
#         id  year  year_rank            group_name  \
# 0     8964  2007         93         LUTHER INGRAM
# 1     9855  1992         39                M.I.A.
# 2      939  1966         56       HURRICANE SMITH
# 3     9350  1970         98           KAI WINDING
# 4     4745  2013         20      BELINDA CARLISLE
# ...    ...   ...        ...                   ...
# 9995  4048  2005         52               DA BRAT
# 9996  5301  1977         62       ZAGER AND EVANS
# 9997  1283  1993         32     BLACKOUT ALLSTARS
# 9998  3639  1980         66  EMINEM FEAT. RIHANNA
# 9999  2539  1993         75   SHAKESPEAR'S SISTER
#
#                                artist  \
# 0                         David Gates
# 1                   SISTER JANET MEAD
# 2     ENGLAND DAN AND JOHN FORD COLEY
# 3                    LOVE AND ROCKETS
# 4                      MASON WILLIAMS
# ...                               ...
# 9995                        EIGHTBALL
# 9996                       DON HENLEY
# 9997                           Prince
# 9998                      Dara Sedaka
# 9999                      Bent Fabric
#
#                                                  song
# 0                                          La Tortura
# 1                        Do It (Til You're Satisfied)
# 2                                 Take A Chance On Me
# 3                                       Sweet Nothing
# 4                                 California Dreamin'
# ...                                               ...
# 9995                                   Girls Nite Out
# 9996                                Come Softly To Me
# 9997  Where Were You (When the World Stopped Turning)
# 9998      Fading Like A Flower (Every Time You Leave)
# 9999                     The First Cut Is The Deepest
#
# [10000 rows x 6 columns]

# %%
year_2010=df[df['year']==2010]
res=year_2010.sort_values(by='year_rank',ascending=True)
#drop duplicates
res=res.drop_duplicates(subset='group_name',keep='first')
res=res.head(10)
#get only the year_rank, group_name, artist, song columns
res=res[['year_rank','group_name','artist','song']]
res
# Out:
#       year_rank             group_name          artist  \
# 5527          1                   ABBA      DIANA ROSS
# 2632          1                    HOT        Gillette
# 3173          1          PATRIC SWAYZE     DEMI LOVATO
# 9896          1              JOE JONES     Dirty Vegas
# 7969          2  TONY ORLANDO AND DAWN        COASTERS
# 969           3           DEON JACKSON    KEVIN MCCALL
# 2770          3           JAMES TAYLOR    GEORGIE FAME
# 8794          3                 WINGER           Lmfao
# 7442          4       PLIES FEAT. AKON           Kandi
# 9403          4            ACE OF BASE  LOVE UNLIMITED
#
#                                     song
# 5527                 You Were On My Mind
# 2632                      Young Emotions
# 3173                 Catch Us If You Can
# 9896                             Pump It
# 7969       Fool (If You Think It's Over)
# 969                   Hate It or Love It
# 2770                           What I Am
# 8794          Don't Cry For Me Argentina
# 7442  Don't Let The Sun Catch You Crying
# 9403   A Little Bit You, A Little Bit Me
