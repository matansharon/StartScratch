description =['S/6 WOODEN SKITTLES IN COTTON BAG', 'SET OF 4 FAIRY CAKE PLACEMATS', 'WOODEN UNION JACK BUNTING', 'NATURAL SLATE RECTANGLE CHALKBOARD', 'VINTAGE UNION JACK APRON', 'PAPER BUNTING WHITE LACE', 'CARDHOLDER GINGHAM CHRISTMAS TREE', 'ENGLISH ROSE NOTEBOOK A7 SIZE', 'STRAWBERRY CHARLOTTE BAG', 'FRENCH LAVENDER SCENT HEART', 'REGENCY TEA PLATE GREEN', 'POTTERING MUG', 'MAGIC DRAWING SLATE CIRCUS PARADE', 'TOY TIDY PINK POLKADOT', 'GLITTER HEART DECORATION', 'I LOVE LONDON BABY GIFT SET', 'MEMO BOARD COTTAGE DESIGN', 'HERB MARKER CHIVES', 'PHARMACIE FIRST AID TIN', "YOU'RE CONFUSING ME METAL SIGN", 'STRAWBERRIES DESIGN FLANNEL', 'Dotcomgiftshop Gift Voucher £50.00', 'PACK OF 12 HEARTS DESIGN TISSUES', 'RIBBON REEL CHRISTMAS PRESENT', 'PACK OF 12 SPACEBOY TISSUES', 'SPACEBOY LUNCH BOX', 'JAM MAKING SET WITH JARS', 'HERB MARKER PARSLEY', 'PACK 20 ENGLISH ROSE PAPER NAPKINS', 'JAZZ HEARTS ADDRESS BOOK', 'CHILDRENS CUTLERY SPACEBOY', 'GLASS APOTHECARY BOTTLE PERFUME', 'TEA TIME OVEN GLOVE', 'WOODEN SCHOOL COLOURING SET', 'PANTRY MAGNETIC SHOPPING LIST', 'PANTRY SCRUBBING BRUSH', 'BREAD BIN DINER STYLE IVORY', 'CHARLOTTE BAG PINK POLKADOT', 'CREAM SLICE FLANNEL CHOCOLATE SPOT', 'PACK OF 12 TRADITIONAL CRAYONS', "50'S CHRISTMAS GIFT BAG LARGE", 'WRAP MAGIC FOREST', 'PINK ENAMEL+GLASS HAIR COMB', "YOU'RE CONFUSING ME METAL SIGN", 'CHOCOLATE HOT WATER BOTTLE', 'SET OF 72 GREEN PAPER DOILIES', 'SET OF 36 DOILIES PANTRY DESIGN', 'BLOND DOLL DOORSTOP', 'RED RETROSPOT PEG BAG', 'LETTER "H" BLING KEY RING', 'RED SPOT GIFT BAG LARGE', 'REX CASH+CARRY JUMBO SHOPPER', 'LUNCH BAG SPACEBOY DESIGN', 'PINK VINTAGE SPOT BEAKER', 'ENAMEL BREAD BIN CREAM', 'RED WOOLLY HOTTIE WHITE HEART.', 'ABC TREASURE BOOK BOX', 'BASKET OF TOADSTOOLS', 'VINTAGE CHRISTMAS GIFT SACK', 'LUNCH BAG PINK POLKADOT', 'SMALL WHITE HEART OF WICKER', 'TUMBLER, BAROQUE', 'PAPER BUNTING RETROSPOT', 'RED GINGHAM TEDDY BEAR', 'COLOURING PENCILS BROWN TUBE', 'BOYS ALPHABET IRON ON PATCHES', 'RED RETROSPOT PURSE', 'REGENCY CAKESTAND 3 TIER', 'DOLLY GIRL BABY GIFT SET', 'JUMBO STORAGE BAG SKULLS', 'JAZZ HEARTS PURSE NOTEBOOK', 'FELTCRAFT CUSHION BUTTERFLY', 'IVORY SWEETHEART SOAP DISH', 'CREAM FELT EASTER EGG BASKET', 'LUNCH BAG SPACEBOY DESIGN', 'PLASTERS IN TIN SPACEBOY', 'RECIPE BOX RETROSPOT', 'LOVE HOT WATER BOTTLE', 'RED DRAWER KNOB ACRYLIC EDWARDIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN', 'SINGLE HEART ZINC T-LIGHT HOLDER', 'SET 2 TEA TOWELS I LOVE LONDON', 'SET OF 6 T-LIGHTS SNOWMEN', 'VINTAGE RED ENAMEL TRIM PLATE', 'HEN HOUSE DECORATION', 'TRAVEL CARD WALLET TRANSPORT', 'FOOD/DRINK SPONGE STICKERS', 'MAGNETS PACK OF 4 SWALLOWS', 'PAINTED METAL STAR WITH HOLLY BELLS', 'BUNDLE OF 3 RETRO NOTE BOOKS', 'LAVENDER SCENTED FABRIC HEART', 'I LOVE LONDON BABY GIFT SET', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'IVORY PILLAR CANDLE SILVER FLOCK', 'ALARM CLOCK BAKELIKE CHOCOLATE', 'HEART OF WICKER LARGE', 'SET OF 6 GIRLS CELEBRATION CANDLES', 'WHITE ROCKING HORSE HAND PAINTED', 'RED DINER WALL CLOCK', 'VINTAGE DOILY TRAVEL SEWING KIT', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE', 'PAPER BUNTING WHITE LACE']
quantity =[3, 3, 3, 5, 3, 40, 6, 1, 10, 1, 1, 12, 1, 4, 13, 1, 4, 1, 1, 1, 1, 1, 1, 15, 24, 12, 3, 12, 9, 1, 4, 1, 4, 12, 6, 2, 1, 4, 1, 24, 2, 25, 1, 1, 24, 1, 12, 2, 7, 1, 12, 1, 2, 1, 1, 25, 3, -408, 4, 10, 3, 1, 12, 1, -1, 3, 1, 3, 2, 10, 1, 4, 6, 6, 40, 12, 6, 4, 1, 1, 12, 6, 2, 12, 2, 1, 50, -6, 5, 1, 20, 1, 2, 1, 4, 3, 1, 24, 1, 5, 20, 12, 1, 10, 2, 1, 1, 10]
unitprice =[2.95, 3.29, 4.96, 3.29, 6.95, 2.55, 3.25, 0.42, 0.85, 1.63, 3.29, 1.25, 0.42, 2.1, 0.39, 16.95, 4.95, 1.63, 13.29, 1.69, 1.63, 41.67, 0.85, 1.65, 0.29, 1.95, 4.25, 0.65, 1.63, 0.19, 4.15, 3.95, 1.25, 1.65, 1.45, 1.65, 16.95, 1.63, 5.79, 0.42, 2.46, 0.42, 2.11, 4.13, 4.25, 1.45, 1.45, 1.25, 4.96, 0.85, 1.25, 0.95, 4.13, 0.85, 12.75, 9.13, 2.25, 1.06, 4.15, 1.65, 3.29, 12.46, 2.95, 5.79, 1.25, 0.42, 5.79, 12.75, 16.95, 2.08, 0.39, 3.75, 2.49, 1.65, 1.65, 1.65, 2.95, 5.95, 2.46, 1.63, 0.95, 3.25, 2.95, 1.65, 1.65, 0.83, 0.21, 1.25, 1.45, 1.65, 1.25, 24.96, 2.08, 0.79, 3.75, 5.91, 1.25, 1.25, 8.5, 1.95, 2.55, 2.55, 2.55, 2.55, 2.55, 2.55, 2.55, 2.55]
customerid=[17338.0, 'nan', 'nan', 'nan', 12371.0, 13001.0, 15748.0, 16121.0, 16923.0, 'nan', 'nan', 13001.0, 12754.0, 14606.0, 16110.0, 12748.0, 16816.0, 'nan', 'nan', 13232.0, 'nan', 'nan', 'nan', 18077.0, 15764.0, 17735.0, 12841.0, 13869.0, 'nan', 13521.0, 12631.0, 15996.0, 16978.0, 13721.0, 14653.0, 13259.0, 14544.0, 'nan', 'nan', 14631.0, 'nan', 13655.0, 'nan', 'nan', 17183.0, 14729.0, 15628.0, 15006.0, 'nan', 'nan', 14759.0, 13230.0, 'nan', 'nan', 13468.0, 'nan', 14057.0, 13984.0, 13871.0, 16722.0, 'nan', 'nan', 13509.0, 'nan', 14056.0, 'nan', 'nan', 12682.0, 12836.0, 16945.0, 16916.0, 13450.0, 12994.0, 15281.0, 'nan', 15544.0, 14466.0, 14936.0, 'nan', 14096.0, 16227.0, 12520.0, 17757.0, 14329.0, 15918.0, 'nan', 16657.0, 12748.0, 15555.0, 14534.0, 13874.0, 'nan', 14156.0, 18005.0, 17719.0, 'nan', 'nan', 13430.0, 15570.0, 17379.0, 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
country =['United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Switzerland', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Japan', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Finland', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'France', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Hong Kong', 'United Kingdom', 'United Kingdom', 'Channel Islands', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Germany', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'EIRE', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom']

df=pd.DataFrame({'InvoiceNo':invoiceno,'StockCode':stockcode,'Description':description,'Quantity':quantity,'InvoiceDate':dates,'UnitPrice':unitprice,'CustomerID':customerid,'Country':country})
df
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      544586     21890   S/6 WOODEN SKITTLES IN COTTON BAG         3
# 1      541104    84509G       SET OF 4 FAIRY CAKE PLACEMATS         3
# 2      560772     22499           WOODEN UNION JACK BUNTING         3
# 3      555150     22488  NATURAL SLATE RECTANGLE CHALKBOARD         5
# 4      570521     21625            VINTAGE UNION JACK APRON         3
# ..        ...       ...                                 ...       ...
# 103        14     22087            PAPER BUNTING WHITE LACE        10
# 104        15     22087            PAPER BUNTING WHITE LACE         2
# 105        16     22087            PAPER BUNTING WHITE LACE         1
# 106        17     22087            PAPER BUNTING WHITE LACE         1
# 107        18     22087            PAPER BUNTING WHITE LACE        10
#
#     InvoiceDate  UnitPrice CustomerID         Country
# 0    2011-02-21       2.95    17338.0  United Kingdom
# ...

# %%
res={}
for i in range(len(df)):
    row=df.iloc[i]
    date=row['InvoiceDate']
    date=date.split('-')
    month=int(date[1])
    if month not in res:
        res[month]={'month':month,'description':row.Description,'total_paid':row.Quantity*row.UnitPrice}
# Out:
# 2
# 1
# 7
# 5
# 10
# 3
# 10
# 10
# 11
# 7
# 9
# 5
# 2
# 1
# 10
# 11
# 1
# 5
# 10
# 4
# 12
# 6
# 12
# 12
# 3
# 4
# 7
# 8
# 1
# 12
# 10
# 8
# 9
# 11
# 10
# 10
# 11
# 11
# 9
# 4
# 10
# 8
# 12
# 7
# 10
# 12
# 6
# 10
# 9
# 12
# 12
# 2
# 1
# 6
# 8
# 11
# 6
# 7
# 11
# 8
# 8
# 1
# 12
# 11
# 10
# 9
# 11
# 2
# 10
# 11
# 11
# 5
# 12
# 2
# 1
# 2
# 2
# 11
# 2
# 11
# 4
# 9
# 10
# 6
# 3
# 9
# 7
# 3
# 12
# 6
# 12
# 7
# 8
# 12
# 6
# 12
# 12
# 11
# 12
# 11
# 5
# 7
# 8
# 7
# 6
# 4
# 2
# 1
