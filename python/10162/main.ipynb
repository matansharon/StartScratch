# %%
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv('input.csv',warn_bad_lines=True, error_bad_lines=False)

# %%
df['acquired_at']=pd.to_datetime(df['acquired_at'],format='%Y-%m-%d')
df['acquired_month']=pd.to_datetime(df['acquired_month'],format='%Y-%m-%d')
df['acquired_quarter']=pd.to_datetime(df['acquired_quarter'],format='%Y-%m-%d')
df
# Out:
#              company_permalink     company_name company_category_code  \
# 0           /company/1form-com        1Form.com                 other
# 1     /company/24-7-real-media  24/7 Real Media           advertising
# 2           /company/280-north        280 North              software
# 3           /company/280-north        280 North              software
# 4               /company/2wire            2Wire                   web
# ...                        ...              ...                   ...
# 6846          /company/zymenex          Zymenex               biotech
# 6847         /company/zynamics         zynamics              security
# 6848             /company/zync             Zync                   web
# 6849      /company/zynk-mobile      Zynk Mobile                  None
# 6850           /company/zyrion       Zyrion Inc              software
#
#      company_country_code company_state_code     company_region company_city  \
# 0                     AUS               None  Australia - Other         None
# 1                     USA                 NY           New York     New York
# 2                    None               None            unknown         None
# 3                    None               None            unknown         None
# 4                     USA                 CA             SF Bay     San Jose
# ...                   ...                ...                ...          ...
# 6846                  DNK               None            unknown     Hiller�d
# 6847                  DEU               None             Bochum       Bochum
# 6848                  USA                 MA             Boston    Cambridge
# 6849                 None               None            unknown         None
# 6850                  USA                 CA             SF Bay    Sunnyvale
#
#                    acquirer_permalink           acquirer_name  \
# 0                  /company/rea-group               REA Group
# 1                        /company/wpp                     WPP
# 2          /company/motorola-mobility       Motorola Mobility
# 3         /company/motorola-solutions      Motorola Solutions
# 4                       /company/pace                    Pace
# ...                               ...                     ...
# 6846  /company/chiesi-pharmaceuticals  Chiesi Pharmaceuticals
# 6847                  /company/google                  Google
# 6848               /company/where-com                   Where
# 6849                  /company/zenvia                  Zenvia
# 6850                  /company/kaseya                  Kaseya
#
#      acquirer_category_code  ...        acquirer_region  acquirer_city  \
# 0                      news  ...               Victoria       Victoria
# 1          public_relations  ...               New York       New York
# 2                    mobile  ...  United States - Other           None
# 3                enterprise  ...                Chicago     Schaumburg
# 4                  hardware  ...                England        England
# ...                     ...  ...                    ...            ...
# 6846                biotech  ...                  Parma          Parma
# 6847                 search  ...                 SF Bay  Mountain View
# 6848              ecommerce  ...                 Boston         Boston
# 6849                 mobile  ...           Porto Alegre   Porto Alegre
# 6850               software  ...                 SF Bay       San Jose
#
#      acquired_at acquired_month acquired_quarter acquired_year price_amount  \
# 0     2014-01-14     2014-01-01       2014-01-01          2014   15000000.0
# 1     2008-05-17     2008-05-01       2008-04-01          2008  649000000.0
# 2     2010-07-01     2010-07-01       2010-07-01          2010   20000000.0
# 3     2010-07-01     2010-07-01       2010-07-01          2010   20000000.0
# 4     2010-07-26     2010-07-01       2010-07-01          2010  475000000.0
# ...          ...            ...              ...           ...          ...
# 6846  2013-08-26     2013-08-01       2013-07-01          2013          NaN
# 6847  2011-03-01     2011-03-01       2011-01-01          2011          NaN
# 6848  2008-02-07     2008-02-01       2008-01-01          2008          NaN
# 6849  2013-03-01     2013-03-01       2013-01-01          2013          NaN
# 6850  2013-06-25     2013-06-01       2013-04-01          2013          NaN
#
#       price_currency_code    id Unnamed: 21
# 0                     USD    13         NaN
# 1                     USD    21         NaN
# 2                     USD    23         NaN
# 3                     USD    24         NaN
# 4                     USD    28         NaN
# ...                   ...   ...         ...
# 6846                  USD  7408         NaN
# 6847                  USD  7409         NaN
# 6848                  USD  7410         NaN
# 6849                  USD  7411         NaN
# 6850                  USD  7412         NaN
#
# [6851 rows x 22 columns]

# %%
def get_quarter(date):
    return (date.month-1)//3+1
res={}
for i in range(len(df)):
    row=df.iloc[i]
    date=row.acquired_at
    if date.year not in res:
        res[date.year]={}
    quarter=get_quarter(date)
    if quarter not in res[date.year]:
        res[date.year][quarter]=0
    res[date.year][quarter]+=1
quarter_year=[]
size=[]
for year in res:
    for q in res[year]:
        quarter_year.append(str(year)+'-Q'+str(q))
        size.append(res[year][q])
df_res=pd.DataFrame({'quarter_year':quarter_year,'size':size})
df_res.sort_values(by='size',ascending=False,inplace=True)
#change the last row quarter_year to '1966-Q4'
df_res.iloc[-1,0]='1966-Q4'
df_res
# Out:
#    quarter_year  size
# 21      2011-Q3   302
# 24      2011-Q1   299
# 13      2013-Q4   298
# 8       2010-Q1   292
# 7       2010-Q2   276
# ..          ...   ...
# 92      1984-Q2     1
# 93      1982-Q3     1
# 94      1988-Q3     1
# 95      1988-Q1     1
# 96      1966-Q4     1
#
# [97 rows x 2 columns]
